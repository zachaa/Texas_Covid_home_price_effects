# %%
#import dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
from pathlib import Path
import pandas as pd
from src.get_project_data import housing_data

# %%
#set path to CSV file
housing_df= housing_data("tx")

#show all Texas housing data
housing_df.head()
# Out:
#         date  zipcode            zip_name  median_listing_price  \
# 0 2023-03-01    78044                 NaN                250000
# 1 2023-03-01    79853        tornillo, tx                167000
# 2 2023-03-01    78404  corpus christi, tx                232428
# 3 2023-03-01    77418       bellville, tx                390000
# 4 2023-03-01    77414        bay city, tx                243968
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   0.1392                   2.1250                     1
# 1                  -0.0089                      NaN                     1
# 2                   0.2304                  -0.1270                    29
# 3                   0.0169                  -0.0835                    35
# 4                  -0.0021                   0.1494                   130
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...

# %%
#Group data by month

monthly_averages= housing_df.groupby(housing_df['date'])['average_listing_price'].mean()

# %%
#show monthly averages
monthly_averages
# Out:
# date
# 2016-07-01    325664.160047
# 2016-08-01    291952.226976
# 2016-09-01    291861.430605
# 2016-10-01    292160.850473
# 2016-11-01     300552.67614
#                   ...
# 2022-11-01      465159.4821
# 2022-12-01    466729.969625
# 2023-01-01    467181.643713
# 2023-02-01    473002.953293
# 2023-03-01    484666.486874
# Name: average_listing_price, Length: 81, dtype: Float64

# %%
#find trends over texas housing prices
fig, ax = plt.subplots(figsize=(11, 6))
monthly_averages.plot()
ax.set_title("Texas Housing Prices")
ax.set_xlabel("Year")
ax.set_ylabel("Average Listing Price")
ax.vlines(x=pd.Timestamp("2020-3-01"), ymin=280000, ymax=500000, color='red', linestyle='--')
ax.title.set_size(20)
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
plt.show()

# %%
#set path to CSV file
housing_df= housing_data("tx")

# %%
#show all Texas housing data
housing_df.head()
# Out:
#         date  zipcode            zip_name  median_listing_price  \
# 0 2023-03-01    78044                 NaN                250000
# 1 2023-03-01    79853        tornillo, tx                167000
# 2 2023-03-01    78404  corpus christi, tx                232428
# 3 2023-03-01    77418       bellville, tx                390000
# 4 2023-03-01    77414        bay city, tx                243968
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                   0.1392                   2.1250                     1
# 1                  -0.0089                      NaN                     1
# 2                   0.2304                  -0.1270                    29
# 3                   0.0169                  -0.0835                    35
# 4                  -0.0021                   0.1494                   130
#
#    active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# ...

# %%
#Group data by year
yearly_averages= housing_df.groupby(housing_df['date'].dt.year)['average_listing_price'].mean()

# %%
#show yearly averages
yearly_averages
# Out:
# date
# 2016    299819.848595
# 2017    306975.098544
# 2018    319321.078294
# 2019    321835.549728
# 2020    343105.877218
# 2021    401302.508312
# 2022     470221.41557
# 2023    474961.983453
# Name: average_listing_price, dtype: Float64

# %%
#find trends over texas housing prices using a bar chart
fig, ax = plt.subplots(figsize=(11, 6))
yearly_averages.plot(kind='bar')
ax.set_title("Texas Housing Prices")
ax.set_xlabel("Year")
ax.set_ylabel("Average Listing Price")


ax.title.set_size(20)
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
#draw a sloped line for the first 4 items in the list
ax.plot([0,1,2,3], [299819.848, 306975.098, 319321.078, 321835.549], color='red', linestyle='-')
ax.plot([3,4,5,6,7],[321835.549, 343105.877, 401302.508, 470221.415, 474961.983], color='red', linestyle='-')
#draw a vertical line at start of pandemic
ax.vlines(x=3.89, ymin=0, ymax=500000, color='red', linestyle='--')

plt.show()
